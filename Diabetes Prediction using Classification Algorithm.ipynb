# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data1  =pd.read_csv('diabetes.csv')

# %% [markdown]
# - Pregnancies: Number of times pregnant
# - Glucose: Plasma glucose concentration over 2 hours in an oral glucose tolerance test
# - BloodPressure: Diastolic blood pressure (mm Hg)
# - SkinThickness: Triceps skin fold thickness (mm)
# - Insulin: 2-Hour serum insulin (mu U/ml)
# - BMI: Body mass index (weight in kg/(height in m)2)
# - DiabetesPedigreeFunction: Diabetes pedigree function (a function which scores likelihood of diabetes based on family history)
# - Age: Age (years)
# - Outcome: Class variable (0 if non-diabetic, 1 if diabetic)

# %%
data1
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
data1['SkinThickness'].describe()
# Out:
# count    768.000000
# mean      20.536458
# std       15.952218
# min        0.000000
# 25%        0.000000
# 50%       23.000000
# 75%       32.000000
# max       99.000000
# Name: SkinThickness, dtype: float64

# %%
data1['SkinThickness'] = data1['SkinThickness'].replace(0,5)

# %%
data1['SkinThickness'].describe()
# Out:
# count    768.000000
# mean      22.014323
# std       14.103401
# min        5.000000
# 25%        5.000000
# 50%       23.000000
# 75%       32.000000
# max       99.000000
# Name: SkinThickness, dtype: float64

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
# Pregnancies                 768 non-null int64
# Glucose                     768 non-null int64
# BloodPressure               768 non-null int64
# SkinThickness               768 non-null int64
# Insulin                     768 non-null int64
# BMI                         768 non-null float64
# DiabetesPedigreeFunction    768 non-null float64
# Age                         768 non-null int64
# Outcome                     768 non-null int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
sns.heatmap(data1.corr(),annot=True)

# %%
# changing all the pregnancy values more than *10 to 10*
p1 = data1[data1['Pregnancies']>10]
p1.reset_index()
# Out:
#     index  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0      24           11      143             94             33      146  36.6
# 1      28           13      145             82             19      110  22.2
# 2      36           11      138             76              5        0  33.2
# 3      72           13      126             90              5        0  43.4
# 4      86           13      106             72             54        0  36.6
# 5      88           15      136             70             32      110  37.1
# 6     159           17      163             72             41      114  40.9
# 7     193           11      135              0              5        0  52.3
# 8     215           12      151             70             40      271  41.8
# 9     254           12       92             62              7      258  27.6
# 10    259           11      155             76             28      150  33.3
# ...

# %%
p1['Pregnancies'] = 10
# Out:
# /home/lokesh/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
p1
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 24            10      143             94             33      146  36.6
# 28            10      145             82             19      110  22.2
# 36            10      138             76              5        0  33.2
# 72            10      126             90              5        0  43.4
# 86            10      106             72             54        0  36.6
# 88            10      136             70             32      110  37.1
# 159           10      163             72             41      114  40.9
# 193           10      135              0              5        0  52.3
# 215           10      151             70             40      271  41.8
# 254           10       92             62              7      258  27.6
# 259           10      155             76             28      150  33.3
# 274           10      106             70              5        0  34.2
# ...

# %%
data2 = data1[data1['Pregnancies']<=10]

# %%
data2
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              5        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              5        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
data = pd.concat([p1, data2])

# %%
data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 24            10      143             94             33      146  36.6
# 28            10      145             82             19      110  22.2
# 36            10      138             76              5        0  33.2
# 72            10      126             90              5        0  43.4
# 86            10      106             72             54        0  36.6
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              5        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 24                      0.254   51        1
# ...

# %%
data = data.reset_index()

# %%
data = data.drop(['index'],axis=1)

# %%
data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0             10      143             94             33      146  36.6
# 1             10      145             82             19      110  22.2
# 2             10      138             76              5        0  33.2
# 3             10      126             90              5        0  43.4
# 4             10      106             72             54        0  36.6
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              5        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.254   51        1
# ...

# %%
data = data[data['Glucose']>0]

# %%
data['Glucose'].describe()
# Out:
# count    763.000000
# mean     121.686763
# std       30.535641
# min       44.000000
# 25%       99.000000
# 50%      117.000000
# 75%      141.000000
# max      199.000000
# Name: Glucose, dtype: float64

# %%
data['BloodPressure'].describe()
# Out:
# count    763.000000
# mean      69.115334
# std       19.399240
# min        0.000000
# 25%       62.000000
# 50%       72.000000
# 75%       80.000000
# max      122.000000
# Name: BloodPressure, dtype: float64

# %%
data[(data['BloodPressure']==0) & (data['Insulin']==0)]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 7             10      135              0              5        0  52.3
# 15            10      129              0             30        0  39.9
# 41            10      115              0              5        0  35.3
# 49             7      100              0              5        0  30.0
# 80             7      105              0              5        0   0.0
# 91             2       84              0              5        0   0.0
# 108            0      131              0              5        0  43.2
# 111            2       74              0              5        0   0.0
# 199            2       87              0             23        0  28.9
# 247            7      119              0              5        0  25.2
# 284            3      141              0              5        0  30.0
# 289            0      138              0              5        0  36.3
# ...

# %%
data['BMI'].describe()
# Out:
# count    763.000000
# mean      31.986763
# std        7.893221
# min        0.000000
# 25%       27.300000
# 50%       32.000000
# 75%       36.550000
# max       67.100000
# Name: BMI, dtype: float64

# %%
p1 = data[data['BMI']==0]

# %%
p1
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  BMI  \
# 43             8      125             96              5        0  0.0
# 80             7      105              0              5        0  0.0
# 91             2       84              0              5        0  0.0
# 111            2       74              0              5        0  0.0
# 173            0      102             75             23        0  0.0
# 388            0      118             64             23       89  0.0
# 442            0       94              0              5        0  0.0
# 508            3       80              0              5        0  0.0
# 534            6      114              0              5        0  0.0
# 688            5      136             82              5        0  0.0
# 709           10      115              0              5        0  0.0
#
#      DiabetesPedigreeFunction  Age  Outcome
# 43                      0.232   54        1
# ...

# %%
p1['BMI']=10
# Out:
# /home/lokesh/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
data = data[data['BMI']>0]

# %%
data1 = pd.concat([data,p1])

# %%
data = data1.copy()

# %%
data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0             10      143             94             33      146  36.6
# 1             10      145             82             19      110  22.2
# 2             10      138             76              5        0  33.2
# 3             10      126             90              5        0  43.4
# 4             10      106             72             54        0  36.6
# ..           ...      ...            ...            ...      ...   ...
# 442            0       94              0              5        0  10.0
# 508            3       80              0              5        0  10.0
# 534            6      114              0              5        0  10.0
# 688            5      136             82              5        0  10.0
# 709           10      115              0              5        0  10.0
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.254   51        1
# ...

# %%
data['DiabetesPedigreeFunction'].describe()
# Out:
# count    763.000000
# mean       0.472477
# std        0.331963
# min        0.078000
# 25%        0.243500
# 50%        0.374000
# 75%        0.626500
# max        2.420000
# Name: DiabetesPedigreeFunction, dtype: float64

# %%
data['Insulin'].describe()
# Out:
# count    763.000000
# mean      80.292267
# std      115.457448
# min        0.000000
# 25%        0.000000
# 50%       36.000000
# 75%      128.500000
# max      846.000000
# Name: Insulin, dtype: float64

# %%
data[data['Insulin']]

# %%
data[(data['Insulin']==0) & (data['Outcome']==1)]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 3             10      126             90              5        0  43.4
# 7             10      135              0              5        0  52.3
# 15            10      129              0             30        0  39.9
# 19            10      175             62             30        0  33.6
# 20            10       84             72             31        0  29.7
# ..           ...      ...            ...            ...      ...   ...
# 759            6      190             92              5        0  35.5
# 761            9      170             74             31        0  44.0
# 766            1      126             60              5        0  30.1
# 43             8      125             96              5        0  10.0
# 709           10      115              0              5        0  10.0
#
#      DiabetesPedigreeFunction  Age  Outcome
# 3                       0.583   42        1
# ...

# %%
data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0             10      143             94             33      146  36.6
# 1             10      145             82             19      110  22.2
# 2             10      138             76              5        0  33.2
# 3             10      126             90              5        0  43.4
# 4             10      106             72             54        0  36.6
# ..           ...      ...            ...            ...      ...   ...
# 442            0       94              0              5        0  10.0
# 508            3       80              0              5        0  10.0
# 534            6      114              0              5        0  10.0
# 688            5      136             82              5        0  10.0
# 709           10      115              0              5        0  10.0
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.254   51        1
# ...

# %%
X = data.iloc[:,:-1]
X
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0             10      143             94             33      146  36.6
# 1             10      145             82             19      110  22.2
# 2             10      138             76              5        0  33.2
# 3             10      126             90              5        0  43.4
# 4             10      106             72             54        0  36.6
# ..           ...      ...            ...            ...      ...   ...
# 442            0       94              0              5        0  10.0
# 508            3       80              0              5        0  10.0
# 534            6      114              0              5        0  10.0
# 688            5      136             82              5        0  10.0
# 709           10      115              0              5        0  10.0
#
#      DiabetesPedigreeFunction  Age
# 0                       0.254   51
# 1                       0.245   57
# ...

# %%
y = data['Outcome']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,random_state=100,test_size = 0.3)

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# (534, 8)
# (534,)

# %%
from sklearn.tree import DecisionTreeClassifier
Dc = DecisionTreeClassifier()
Dc.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
y_pred = Dc.predict(X_test)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix
score = accuracy_score(y_test,y_pred)
score
# Out:
# 0.7205240174672489

# %%
score1 = confusion_matrix(y_test,y_pred)
score1
# Out:
# array([[115,  24],
#        [ 40,  50]])

# %%
from sklearn.ensemble import RandomForestClassifier
Rf =RandomForestClassifier()
Rf.fit(X_train,y_train)
y_pred = Rf.predict(X_test)
# Out:
# /home/lokesh/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
score = accuracy_score(y_test,y_pred)
score
# Out:
# 0.7554585152838428

# %%
data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0             10      143             94             33      146  36.6
# 1             10      145             82             19      110  22.2
# 2             10      138             76              5        0  33.2
# 3             10      126             90              5        0  43.4
# 4             10      106             72             54        0  36.6
# ..           ...      ...            ...            ...      ...   ...
# 442            0       94              0              5        0  10.0
# 508            3       80              0              5        0  10.0
# 534            6      114              0              5        0  10.0
# 688            5      136             82              5        0  10.0
# 709           10      115              0              5        0  10.0
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.254   51        1
# ...

# %%
from sklearn.linear_model import LogisticRegression
L = LogisticRegression()
L.fit(X_train,y_train)
y_pred = L.predict(X_test)
# Out:
# /home/lokesh/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
score = accuracy_score(y_test,y_pred)
score
# Out:
# 0.777292576419214

# %%
from sklearn.ensemble import GradientBoostingClassifier
Gr = GradientBoostingClassifier()
Gr.fit(X_train,y_train)
y_pred = Gr.predict(X_test)

# %%
score = accuracy_score(y_test,y_pred)
score
# Out:
# 0.7860262008733624

# %%
def inp(Preg,Gl,BP,SkinThickness,Insulin,BMI,Diab,Age):
    x = np.zeros(len(X.columns))
    x[0]=Preg
    x[1]=Gl
    x[2]=BP
    x[3]=SkinThickness
    x[4]=Insulin
    x[5]=BMI
    x[6]=Diab
    x[7]=Age
    out = Gr.predict([x])[0]
    return out

# %%
inp(10,115,0,5,0,50,0.261,30)
# Out:
# 1
